# %% [markdown]
# # Importing Libraries

# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from scipy import sparse
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.metrics import precision_recall_fscore_support

from pycaret.nlp import *

# %% [markdown]
# # Loading the Data

# %%
df_bg_tmp = pd.read_csv('../datasets/games-cleaned.csv')
df_rv_tmp = pd.read_csv('../datasets/reviews-cleaned.csv')

# %% [markdown]
# # Collaborative Recommenders

# %%
df_bg = df_bg_tmp.copy()
df_rv = df_rv_tmp.copy()

# %%
df_bg.head()
# Out:
#       id         name  rank  geek_rating  avg_rating  usersrated  \
# 0  30549     Pandemic   106      7.48669     7.58896      109006
# 1    822  Carcassonne   191      7.30857     7.41837      108776
# 2     13        Catan   429      6.96965     7.13598      108064
# 3  68448    7 Wonders    73      7.63355     7.73515       90021
# 4  36218     Dominion   104      7.49912     7.61000       81582
#
#                                             category  \
# 0                                        ['Medical']
# 1  ['City Building', 'Medieval', 'Territory Build...
# 2                        ['Economic', 'Negotiation']
# 3  ['Ancient', 'Card Game', 'City Building', 'Civ...
# 4                          ['Card Game', 'Medieval']
#
#                                             mechanic  weight  minplayers  \
# 0  ['Action Points', 'Cooperative Game', 'Hand Ma...  2.4063           2
# 1  ['Area Majority / Influence', 'Map Addition', ...  1.9057           2
# 2  ['Dice Rolling', 'Hexagon Grid', 'Income', 'Mo...  2.3130           3
# 3  ['Drafting', 'Hand Management', 'Set Collectio...  2.3264           2
# 4  ['Deck, Bag, and Pool Building', 'Delayed Purc...  2.3542           2
#
#    maxplayers  playingtime  minage  yearpublished                 designer  \
# 0           4           45       8           2008         ['Matt Leacock']
# 1           5           45       7           2000   ['Klaus-Jürgen Wrede']
# 2           4          120      10           1995         ['Klaus Teuber']
# 3           7           30      10           2010        ['Antoine Bauza']
# 4           4           30      13           2008  ['Donald X. Vaccarino']
#
#                                               artist  \
# 0  ['Josh Cappel', 'Christian Hanisch', 'Régis Mo...
# 1  ['Doris Matthäus', 'Anne Pätzke', 'Chris Quill...
# 2  ['Volkan Baga', 'Tanja Donner', 'Pete Fenlon',...
# 3  ['Dimitri Chappuis', 'Miguel Coimbra', 'Etienn...
# 4  ['Matthias Catrein', 'Julien Delval', 'Tomasz ...
#
#                                            publisher  \
# 0  ['Z-Man Games', 'Albi', 'Asmodee', 'Asmodee It...
# 1  ['Hans im Glück', '999 Games', 'Albi', 'Bard C...
# 2  ['KOSMOS', '999 Games', 'Albi', 'Asmodee', 'As...
# 3  ['Repos Production', 'ADC Blackfire Entertainm...
# 4  ['Rio Grande Games', '999 Games', 'Albi', 'Bar...
#
#                                          description  \
# 0  In Pandemic, several virulent diseases have br...
# 1  Carcassonne is a tile-placement game in which ...
# 2  In CATAN (formerly The Settlers of Catan), pla...
# 3  You are the leader of one of the 7 great citie...
# 4  &quot;You are a monarch, like your parents bef...
#
#                                                image
# 0  https://cf.geekdo-images.com/S3ybV1LAp-8SnHIXL...
# 1  https://cf.geekdo-images.com/okM0dq_bEXnbyQTOv...
# 2  https://cf.geekdo-images.com/W3Bsga_uLP9kO91gZ...
# 3  https://cf.geekdo-images.com/RvFVTEpnbb4NM7k0I...
# 4  https://cf.geekdo-images.com/j6iQpZ4XkemZP07HN...

# %%
df_rv.head()
# Out:
#               user               name  rating
# 0  1 Family Meeple  10 Days in Europe     4.1
# 1  1 Family Meeple            12 Days     7.0
# 2  1 Family Meeple          7 Wonders     6.5
# 3  1 Family Meeple   A Column of Fire     5.0
# 4  1 Family Meeple   A Feast for Odin    10.0

# %% [markdown]
# **User-based Collaborative Recommender**

# %%
# User-based pivot table
user_pivot = pd.pivot_table(df_rv, index='user', columns='name', values='rating')
user_pivot
# Out:
# name             ...and then, we held hands.  ...und tschüss!  \
# user
# 1 Family Meeple                          NaN              NaN
# 1000rpm                                  NaN              NaN
# 28green                                  NaN              NaN
# 42amu                                    NaN              NaN
# 549sd                                    NaN              NaN
# ...                                      ...              ...
# zsknight                                 NaN              NaN
# zumba                                    NaN              NaN
# zumikon                                  NaN              8.0
# zunnesteke                               NaN              NaN
# zuzusdad                                 NaN              NaN
#
# name             10 Days in Africa  10 Days in Asia  10 Days in Europe  \
# user
# 1 Family Meeple                NaN              NaN                4.1
# 1000rpm                        NaN              NaN                7.0
# 28green                        NaN              NaN                7.0
# 42amu                          NaN              NaN                NaN
# 549sd                          NaN              NaN                NaN
# ...                            ...              ...                ...
# zsknight                       NaN              NaN                NaN
# zumba                          4.0              NaN                NaN
# zumikon                        6.5              NaN                NaN
# zunnesteke                     NaN              NaN                NaN
# zuzusdad                       NaN              NaN                NaN
#
# name             10 Days in the Americas  10 Days in the USA  \
# user
# 1 Family Meeple                      NaN                 NaN
# 1000rpm                              NaN                 NaN
# 28green                              NaN                 7.0
# 42amu                                NaN                 NaN
# 549sd                                NaN                 6.0
# ...                                  ...                 ...
# zsknight                             NaN                 NaN
# zumba                                NaN                 NaN
# zumikon                              NaN                 7.0
# zunnesteke                           NaN                 NaN
# zuzusdad                             NaN                 NaN
#
# name             10 Minute Heist: The Wizard's Tower  10' to Kill  \
# user
# 1 Family Meeple                                  NaN          NaN
# 1000rpm                                          NaN          NaN
# 28green                                          NaN          NaN
# 42amu                                            NaN          8.0
# 549sd                                            NaN          NaN
# ...                                              ...          ...
# zsknight                                         NaN          NaN
# zumba                                            NaN          NaN
# zumikon                                          NaN          NaN
# zunnesteke                                       NaN          NaN
# zuzusdad                                         NaN          NaN
#
# name             1000 Blank White Cards  ...  Zooloretto Junior  \
# user                                     ...
# 1 Family Meeple                     NaN  ...                NaN
# 1000rpm                             NaN  ...                NaN
# 28green                             NaN  ...                NaN
# 42amu                               NaN  ...                NaN
# 549sd                               NaN  ...                NaN
# ...                                 ...  ...                ...
# zsknight                            NaN  ...                NaN
# zumba                               NaN  ...                NaN
# zumikon                             NaN  ...                NaN
# zunnesteke                          NaN  ...                NaN
# zuzusdad                            NaN  ...                NaN
#
# name             Zooloretto: The Dice Game  Zoowaboo  Zug um Zug: Deutschland  \
# user
# 1 Family Meeple                        NaN       NaN                      NaN
# 1000rpm                                7.0       NaN                      NaN
# 28green                                NaN       NaN                      NaN
# 42amu                                  NaN       NaN                      NaN
# 549sd                                  NaN       NaN                      NaN
# ...                                    ...       ...                      ...
# zsknight                               NaN       NaN                      NaN
# zumba                                  NaN       6.0                      NaN
# zumikon                                7.5       NaN                      NaN
# zunnesteke                             NaN       NaN                      NaN
# zuzusdad                               NaN       NaN                      NaN
#
# name             Zulus on the Ramparts!: The Battle of Rorke's Drift – Second Edition  \
# user
# 1 Family Meeple                                                NaN
# 1000rpm                                                        NaN
# 28green                                                        NaN
# 42amu                                                          NaN
# 549sd                                                          NaN
# ...                                                            ...
# zsknight                                                       NaN
# zumba                                                          NaN
# zumikon                                                        NaN
# zunnesteke                                                     NaN
# zuzusdad                                                       NaN
#
# name             ZÈRTZ  [redacted]  duck! duck! Go!  ebbes  iKNOW
# user
# 1 Family Meeple    NaN         6.5              4.0    NaN    NaN
# 1000rpm            NaN         NaN              NaN    NaN    NaN
# 28green            NaN         NaN              NaN    NaN    NaN
# 42amu              NaN         NaN              NaN    NaN    NaN
# 549sd              NaN         5.0              NaN    NaN    NaN
# ...                ...         ...              ...    ...    ...
# zsknight           NaN         NaN              NaN    6.2    NaN
# zumba              7.0         NaN              4.0    6.0    NaN
# zumikon            NaN         7.5              NaN    NaN    NaN
# zunnesteke         7.0         NaN              NaN    NaN    NaN
# zuzusdad           NaN         NaN              NaN    NaN    NaN
#
# [3067 rows x 4582 columns]

# %%
# Sparse matrix
sparse_user_pivot = sparse.csr_matrix(user_pivot.fillna(0))

# Convert type to save memory
sparse_user_pivot = sparse_user_pivot.astype(np.float32)

sparse_user_pivot
# Out:
# <3067x4582 sparse matrix of type '<class 'numpy.float32'>'
# 	with 2018715 stored elements in Compressed Sparse Row format>

# %%
# Similarity matrix
user_similarities = cosine_similarity(sparse_user_pivot)
user_similarities
# Out:
# array([[1.0000013 , 0.35132778, 0.44122967, ..., 0.33333313, 0.32253665,
#         0.40138492],
#        [0.35132778, 1.000003  , 0.38480732, ..., 0.358057  , 0.28843167,
#         0.3961942 ],
#        [0.44122967, 0.38480732, 0.9999994 , ..., 0.32477707, 0.28985673,
#         0.45373744],
#        ...,
#        [0.33333313, 0.358057  , 0.32477707, ..., 1.0000007 , 0.460744  ,
#         0.306209  ],
#        [0.32253665, 0.28843167, 0.28985673, ..., 0.460744  , 1.0000017 ,
#         0.2733309 ],
#        [0.40138492, 0.3961942 , 0.45373744, ..., 0.306209  , 0.2733309 ,
#         1.0000002 ]], dtype=float32)

# %%
# Use it as a dataframe
user_cf_df = pd.DataFrame(user_similarities, index=user_pivot.index, columns=user_pivot.index)
user_cf_df.head()
# Out:
# user             1 Family Meeple   1000rpm   28green     42amu     549sd  \
# user
# 1 Family Meeple         1.000001  0.351328  0.441230  0.463583  0.431945
# 1000rpm                 0.351328  1.000003  0.384807  0.314870  0.343502
# 28green                 0.441230  0.384807  0.999999  0.414176  0.423904
# 42amu                   0.463583  0.314870  0.414176  0.999997  0.449813
# 549sd                   0.431945  0.343502  0.423904  0.449813  0.999995
#
# user             AHforever  AJBrandon   ASSaali    Aarkas  AaronBE85  ...  \
# user                                                                  ...
# 1 Family Meeple   0.327051   0.307018  0.348769  0.365398   0.422336  ...
# 1000rpm           0.153420   0.327590  0.341947  0.277185   0.328638  ...
# 28green           0.287099   0.382935  0.345915  0.311133   0.390536  ...
# 42amu             0.357573   0.294944  0.381349  0.405254   0.469776  ...
# 549sd             0.348759   0.383475  0.390232  0.403238   0.501875  ...
#
# user             zhiwiller  zizishaoye   zodball  zottirgen  zpark999  \
# user
# 1 Family Meeple   0.413991    0.387728  0.435491   0.427697  0.428628
# 1000rpm           0.287583    0.364414  0.254238   0.306647  0.342873
# 28green           0.454744    0.414215  0.372633   0.391947  0.457808
# 42amu             0.408089    0.397024  0.433965   0.445356  0.444515
# 549sd             0.475182    0.473047  0.448085   0.474304  0.544098
#
# user             zsknight     zumba   zumikon  zunnesteke  zuzusdad
# user
# 1 Family Meeple  0.434545  0.264001  0.333333    0.322537  0.401385
# 1000rpm          0.345588  0.347187  0.358057    0.288432  0.396194
# 28green          0.396022  0.272193  0.324777    0.289857  0.453737
# 42amu            0.464872  0.300592  0.386128    0.412055  0.370331
# 549sd            0.479252  0.310789  0.365346    0.389563  0.378417
#
# [5 rows x 3067 columns]

# %%
# Similar users scores
user_input = '1 Family Meeple'
user_sim = user_cf_df[user_input].drop(user_input)
user_sim = user_sim[user_sim > 0].sort_values(ascending=False)
user_sim
# Out:
# user
# forgotmypencil     0.542529
# Dugrex56           0.529538
# Wiegrief           0.526229
# StoryBoardGamer    0.518482
# Throat_Rip         0.513059
#                      ...
# pmnj               0.172094
# StoneR             0.165965
# Superfly3          0.165069
# Biscotti           0.147669
# average_joe        0.100825
# Name: 1 Family Meeple, Length: 3066, dtype: float32

# %%
# Turn the similarity scores into weights
user_weight = user_sim.values / np.sum(user_sim)
user_weight
# Out:
# array([4.8418189e-04, 4.7258765e-04, 4.6963498e-04, ..., 1.4731647e-04,
#        1.3178788e-04, 8.9982015e-05], dtype=float32)

# %%
# Ratings for board games by users
user_ratings = user_pivot.T
user_ratings.head()
# Out:
# user                         1 Family Meeple  1000rpm  28green  42amu  549sd  \
# name
# ...and then, we held hands.              NaN      NaN      NaN    NaN    NaN
# ...und tschüss!                          NaN      NaN      NaN    NaN    NaN
# 10 Days in Africa                        NaN      NaN      NaN    NaN    NaN
# 10 Days in Asia                          NaN      NaN      NaN    NaN    NaN
# 10 Days in Europe                        4.1      7.0      7.0    NaN    NaN
#
# user                         AHforever  AJBrandon  ASSaali  Aarkas  AaronBE85  \
# name
# ...and then, we held hands.        NaN        NaN      NaN     NaN        NaN
# ...und tschüss!                    NaN        NaN      NaN     NaN        NaN
# 10 Days in Africa                  NaN        NaN      NaN     NaN        NaN
# 10 Days in Asia                    NaN        NaN      NaN     NaN        NaN
# 10 Days in Europe                  NaN        NaN      NaN     NaN        NaN
#
# user                         ...  zhiwiller  zizishaoye  zodball  zottirgen  \
# name                         ...
# ...and then, we held hands.  ...        NaN         NaN      NaN        NaN
# ...und tschüss!              ...        NaN         NaN      NaN        NaN
# 10 Days in Africa            ...        NaN         7.3      NaN        NaN
# 10 Days in Asia              ...        NaN         7.6      NaN        NaN
# 10 Days in Europe            ...        NaN         7.6      NaN        NaN
#
# user                         zpark999  zsknight  zumba  zumikon  zunnesteke  \
# name
# ...and then, we held hands.       NaN       NaN    NaN      NaN         NaN
# ...und tschüss!                   NaN       NaN    NaN      8.0         NaN
# 10 Days in Africa                 NaN       NaN    4.0      6.5         NaN
# 10 Days in Asia                   NaN       NaN    NaN      NaN         NaN
# 10 Days in Europe                 NaN       NaN    NaN      NaN         NaN
#
# user                         zuzusdad
# name
# ...and then, we held hands.       NaN
# ...und tschüss!                   NaN
# 10 Days in Africa                 NaN
# 10 Days in Asia                   NaN
# 10 Days in Europe                 NaN
#
# [5 rows x 3067 columns]

# %%
# Board games that user has not rated
# Also, drop the user himself
ratings = user_ratings[user_ratings[user_input].isnull()]
ratings = ratings.loc[:, user_sim.index]
ratings
# Out:
# user                                                forgotmypencil  Dugrex56  \
# name
# ...and then, we held hands.                                    NaN       NaN
# ...und tschüss!                                                NaN       NaN
# 10 Days in Africa                                              7.0       NaN
# 10 Days in Asia                                                NaN       NaN
# 10 Days in the Americas                                        NaN       NaN
# ...                                                            ...       ...
# Zug um Zug: Deutschland                                        NaN       NaN
# Zulus on the Ramparts!: The Battle of Rorke's D...             NaN       NaN
# ZÈRTZ                                                          NaN       NaN
# ebbes                                                          NaN       NaN
# iKNOW                                                          NaN       NaN
#
# user                                                Wiegrief  StoryBoardGamer  \
# name
# ...and then, we held hands.                              NaN              6.0
# ...und tschüss!                                          NaN              NaN
# 10 Days in Africa                                        NaN              NaN
# 10 Days in Asia                                          NaN              NaN
# 10 Days in the Americas                                  NaN              NaN
# ...                                                      ...              ...
# Zug um Zug: Deutschland                                  NaN              NaN
# Zulus on the Ramparts!: The Battle of Rorke's D...       NaN              NaN
# ZÈRTZ                                                    NaN              NaN
# ebbes                                                    NaN              NaN
# iKNOW                                                    NaN              NaN
#
# user                                                Throat_Rip  reformedkenny  \
# name
# ...and then, we held hands.                                NaN            6.5
# ...und tschüss!                                            NaN            NaN
# 10 Days in Africa                                          NaN            6.5
# 10 Days in Asia                                            NaN            NaN
# 10 Days in the Americas                                    NaN            NaN
# ...                                                        ...            ...
# Zug um Zug: Deutschland                                    NaN            NaN
# Zulus on the Ramparts!: The Battle of Rorke's D...         NaN            NaN
# ZÈRTZ                                                      NaN            NaN
# ebbes                                                      NaN            NaN
# iKNOW                                                      NaN            NaN
#
# user                                                oatmeal1201  chadams  \
# name
# ...and then, we held hands.                                 NaN      NaN
# ...und tschüss!                                             NaN      NaN
# 10 Days in Africa                                           NaN      NaN
# 10 Days in Asia                                             NaN      NaN
# 10 Days in the Americas                                     NaN      NaN
# ...                                                         ...      ...
# Zug um Zug: Deutschland                                     NaN      NaN
# Zulus on the Ramparts!: The Battle of Rorke's D...          NaN      NaN
# ZÈRTZ                                                       NaN      NaN
# ebbes                                                       NaN      NaN
# iKNOW                                                       NaN      NaN
#
# user                                                Reine Beth  helloworldmy  \
# name
# ...and then, we held hands.                                NaN           NaN
# ...und tschüss!                                            NaN           NaN
# 10 Days in Africa                                          NaN           NaN
# 10 Days in Asia                                            NaN           NaN
# 10 Days in the Americas                                    NaN           NaN
# ...                                                        ...           ...
# Zug um Zug: Deutschland                                    NaN           NaN
# Zulus on the Ramparts!: The Battle of Rorke's D...         NaN           NaN
# ZÈRTZ                                                      NaN           NaN
# ebbes                                                      NaN           NaN
# iKNOW                                                      NaN           NaN
#
# user                                                ...  khronosTdG  malloc  \
# name                                                ...
# ...and then, we held hands.                         ...         NaN     NaN
# ...und tschüss!                                     ...         NaN     NaN
# 10 Days in Africa                                   ...         NaN     5.0
# 10 Days in Asia                                     ...         NaN     NaN
# 10 Days in the Americas                             ...         NaN     NaN
# ...                                                 ...         ...     ...
# Zug um Zug: Deutschland                             ...         NaN     NaN
# Zulus on the Ramparts!: The Battle of Rorke's D...  ...         NaN     NaN
# ZÈRTZ                                               ...         NaN     NaN
# ebbes                                               ...         NaN     NaN
# iKNOW                                               ...         NaN     NaN
#
# user                                                heli  ecoboardgeek123  \
# name
# ...and then, we held hands.                          NaN              NaN
# ...und tschüss!                                      5.0              NaN
# 10 Days in Africa                                    7.0              NaN
# 10 Days in Asia                                      NaN              NaN
# 10 Days in the Americas                              NaN              NaN
# ...                                                  ...              ...
# Zug um Zug: Deutschland                              NaN              NaN
# Zulus on the Ramparts!: The Battle of Rorke's D...   NaN              NaN
# ZÈRTZ                                                6.0              NaN
# ebbes                                                6.0              NaN
# iKNOW                                                NaN              NaN
#
# user                                                Ludo le gars  pmnj  \
# name
# ...and then, we held hands.                                  NaN   NaN
# ...und tschüss!                                              7.5   4.0
# 10 Days in Africa                                            NaN   NaN
# 10 Days in Asia                                              NaN   NaN
# 10 Days in the Americas                                      NaN   NaN
# ...                                                          ...   ...
# Zug um Zug: Deutschland                                      NaN   NaN
# Zulus on the Ramparts!: The Battle of Rorke's D...           NaN   NaN
# ZÈRTZ                                                        6.5   NaN
# ebbes                                                        NaN   NaN
# iKNOW                                                        NaN   NaN
#
# user                                                StoneR  Superfly3  \
# name
# ...and then, we held hands.                            NaN        NaN
# ...und tschüss!                                        8.0        NaN
# 10 Days in Africa                                      6.0        NaN
# 10 Days in Asia                                        6.0        NaN
# 10 Days in the Americas                                7.0        NaN
# ...                                                    ...        ...
# Zug um Zug: Deutschland                                NaN        NaN
# Zulus on the Ramparts!: The Battle of Rorke's D...     NaN        NaN
# ZÈRTZ                                                  6.0        8.0
# ebbes                                                  NaN        NaN
# iKNOW                                                  NaN        NaN
#
# user                                                Biscotti  average_joe
# name
# ...and then, we held hands.                              NaN          NaN
# ...und tschüss!                                          NaN          NaN
# 10 Days in Africa                                        NaN      6.65892
# 10 Days in Asia                                          NaN          NaN
# 10 Days in the Americas                                  NaN          NaN
# ...                                                      ...          ...
# Zug um Zug: Deutschland                                  NaN          NaN
# Zulus on the Ramparts!: The Battle of Rorke's D...       NaN          NaN
# ZÈRTZ                                                    1.0      7.57743
# ebbes                                                    NaN          NaN
# iKNOW                                                    NaN          NaN
#
# [3981 rows x 3066 columns]

# %%
# Predicted ratings
pred_user_ratings = np.dot(ratings.fillna(0), user_weight)

# Observe in dataframe, top 20 recommendations
top_20_rec = pd.DataFrame(pred_user_ratings, index=ratings.index.astype(str), columns=[user_input]).sort_values(by=user_input, ascending=False).head(20)
top_20_rec
# Out:
#                                                1 Family Meeple
# name
# 7 Wonders Duel                                        6.794839
# Lost Cities                                           6.009316
# Dixit                                                 5.990938
# El Grande                                             5.877991
# Russian Railroads                                     5.707936
# Alhambra                                              5.597668
# Tigris & Euphrates                                    5.490876
# Pandemic Legacy: Season 1                             5.297904
# Twilight Struggle                                     5.286731
# The Crew: The Quest for Planet Nine                   5.101501
# Santorini                                             4.984387
# Colt Express                                          4.959740
# Hive                                                  4.893149
# Mombasa                                               4.891046
# Thurn and Taxis                                       4.876611
# Tikal                                                 4.862883
# In the Year of the Dragon                             4.851769
# Targi                                                 4.846617
# Eclipse                                               4.840261
# Through the Ages: A New Story of Civilization         4.803492

# %%
# View board games which user had already rated
user_rated_games = user_ratings[[user_input]]
user_rated_games.index = user_ratings.index.astype(str)
user_rated_games.sort_values(by=user_input, ascending=False).head(20)
# Out:
# user                                    1 Family Meeple
# name
# Cottage Garden                                     10.0
# A Feast for Odin                                   10.0
# Concordia                                          10.0
# Rajas of the Ganges                                10.0
# Rajas of the Ganges: The Dice Charmers             10.0
# Coimbra                                             9.5
# Yokohama                                            9.5
# Terraforming Mars                                   9.5
# Rococo                                              9.0
# Heaven & Ale                                        9.0
# Warsaw: City of Ruins                               9.0
# That's Pretty Clever!                               9.0
# La Granja                                           9.0
# Kingdomino                                          9.0
# Diamonds: Second Edition                            9.0
# Glory to Rome                                       9.0
# Bruges                                              9.0
# Parade                                              9.0
# Above and Below                                     9.0
# Escape from the Aliens in Outer Space               9.0

# %% [markdown]
# **Item-based Collaborative Recommender**

# %%
# User-based pivot table
item_pivot = pd.pivot_table(df_rv, index='name', columns='user', values='rating')
item_pivot
# Out:
# user                         1 Family Meeple  1000rpm  28green  42amu  549sd  \
# name
# ...and then, we held hands.              NaN      NaN      NaN    NaN    NaN
# ...und tschüss!                          NaN      NaN      NaN    NaN    NaN
# 10 Days in Africa                        NaN      NaN      NaN    NaN    NaN
# 10 Days in Asia                          NaN      NaN      NaN    NaN    NaN
# 10 Days in Europe                        4.1      7.0      7.0    NaN    NaN
# ...                                      ...      ...      ...    ...    ...
# ZÈRTZ                                    NaN      NaN      NaN    NaN    NaN
# [redacted]                               6.5      NaN      NaN    NaN    5.0
# duck! duck! Go!                          4.0      NaN      NaN    NaN    NaN
# ebbes                                    NaN      NaN      NaN    NaN    NaN
# iKNOW                                    NaN      NaN      NaN    NaN    NaN
#
# user                         AHforever  AJBrandon  ASSaali  Aarkas  AaronBE85  \
# name
# ...and then, we held hands.        NaN        NaN      NaN     NaN        NaN
# ...und tschüss!                    NaN        NaN      NaN     NaN        NaN
# 10 Days in Africa                  NaN        NaN      NaN     NaN        NaN
# 10 Days in Asia                    NaN        NaN      NaN     NaN        NaN
# 10 Days in Europe                  NaN        NaN      NaN     NaN        NaN
# ...                                ...        ...      ...     ...        ...
# ZÈRTZ                              NaN        NaN      NaN     NaN        NaN
# [redacted]                         NaN        NaN      NaN     NaN        NaN
# duck! duck! Go!                    NaN        NaN      NaN     NaN        NaN
# ebbes                              NaN        NaN      NaN     NaN        NaN
# iKNOW                              NaN        NaN      NaN     NaN        NaN
#
# user                         ...  zhiwiller  zizishaoye  zodball  zottirgen  \
# name                         ...
# ...and then, we held hands.  ...        NaN         NaN      NaN        NaN
# ...und tschüss!              ...        NaN         NaN      NaN        NaN
# 10 Days in Africa            ...        NaN         7.3      NaN        NaN
# 10 Days in Asia              ...        NaN         7.6      NaN        NaN
# 10 Days in Europe            ...        NaN         7.6      NaN        NaN
# ...                          ...        ...         ...      ...        ...
# ZÈRTZ                        ...        8.0         8.0      NaN        NaN
# [redacted]                   ...        5.0         NaN      NaN        NaN
# duck! duck! Go!              ...        NaN         NaN      NaN        NaN
# ebbes                        ...        NaN         NaN      NaN        NaN
# iKNOW                        ...        NaN         6.6      NaN        NaN
#
# user                         zpark999  zsknight  zumba  zumikon  zunnesteke  \
# name
# ...and then, we held hands.       NaN       NaN    NaN      NaN         NaN
# ...und tschüss!                   NaN       NaN    NaN      8.0         NaN
# 10 Days in Africa                 NaN       NaN    4.0      6.5         NaN
# 10 Days in Asia                   NaN       NaN    NaN      NaN         NaN
# 10 Days in Europe                 NaN       NaN    NaN      NaN         NaN
# ...                               ...       ...    ...      ...         ...
# ZÈRTZ                             NaN       NaN    7.0      NaN         7.0
# [redacted]                        NaN       NaN    NaN      7.5         NaN
# duck! duck! Go!                   NaN       NaN    4.0      NaN         NaN
# ebbes                             NaN       6.2    6.0      NaN         NaN
# iKNOW                             NaN       NaN    NaN      NaN         NaN
#
# user                         zuzusdad
# name
# ...and then, we held hands.       NaN
# ...und tschüss!                   NaN
# 10 Days in Africa                 NaN
# 10 Days in Asia                   NaN
# 10 Days in Europe                 NaN
# ...                               ...
# ZÈRTZ                             NaN
# [redacted]                        NaN
# duck! duck! Go!                   NaN
# ebbes                             NaN
# iKNOW                             NaN
#
# [4582 rows x 3067 columns]

# %%
# Sparse matrix
sparse_item_pivot = sparse.csr_matrix(item_pivot.fillna(0))

# Similarity matrix
item_similarities = cosine_similarity(sparse_item_pivot)

# Use it as a dataframe
item_cf_df = pd.DataFrame(item_similarities, index=item_pivot.index, columns=item_pivot.index)
item_cf_df.head()
# Out:
# name                         ...and then, we held hands.  ...und tschüss!  \
# name
# ...and then, we held hands.                     1.000000         0.080115
# ...und tschüss!                                 0.080115         1.000000
# 10 Days in Africa                               0.158781         0.164283
# 10 Days in Asia                                 0.108188         0.135121
# 10 Days in Europe                               0.140938         0.228677
#
# name                         10 Days in Africa  10 Days in Asia  \
# name
# ...and then, we held hands.           0.158781         0.108188
# ...und tschüss!                       0.164283         0.135121
# 10 Days in Africa                     1.000000         0.584768
# 10 Days in Asia                       0.584768         1.000000
# 10 Days in Europe                     0.551947         0.541234
#
# name                         10 Days in Europe  10 Days in the Americas  \
# name
# ...and then, we held hands.           0.140938                 0.108727
# ...und tschüss!                       0.228677                 0.106158
# 10 Days in Africa                     0.551947                 0.481432
# 10 Days in Asia                       0.541234                 0.591203
# 10 Days in Europe                     1.000000                 0.474869
#
# name                         10 Days in the USA  \
# name
# ...and then, we held hands.            0.127127
# ...und tschüss!                        0.131682
# 10 Days in Africa                      0.553647
# 10 Days in Asia                        0.509913
# 10 Days in Europe                      0.520611
#
# name                         10 Minute Heist: The Wizard's Tower  10' to Kill  \
# name
# ...and then, we held hands.                             0.147714     0.141141
# ...und tschüss!                                         0.073456     0.054965
# 10 Days in Africa                                       0.096274     0.070299
# 10 Days in Asia                                         0.078295     0.052857
# 10 Days in Europe                                       0.148301     0.101523
#
# name                         1000 Blank White Cards  ...  Zooloretto Junior  \
# name                                                 ...
# ...and then, we held hands.                0.061741  ...           0.075312
# ...und tschüss!                            0.035974  ...           0.121544
# 10 Days in Africa                          0.134278  ...           0.175300
# 10 Days in Asia                            0.098025  ...           0.157740
# 10 Days in Europe                          0.097216  ...           0.169539
#
# name                         Zooloretto: The Dice Game  Zoowaboo  \
# name
# ...and then, we held hands.                   0.187834  0.076062
# ...und tschüss!                               0.175149  0.139251
# 10 Days in Africa                             0.268873  0.173794
# 10 Days in Asia                               0.237408  0.146475
# 10 Days in Europe                             0.290477  0.212485
#
# name                         Zug um Zug: Deutschland  \
# name
# ...and then, we held hands.                 0.086458
# ...und tschüss!                             0.096781
# 10 Days in Africa                           0.063029
# 10 Days in Asia                             0.068021
# 10 Days in Europe                           0.097823
#
# name                         Zulus on the Ramparts!: The Battle of Rorke's Drift – Second Edition  \
# name
# ...and then, we held hands.                                           0.098297
# ...und tschüss!                                                       0.034480
# 10 Days in Africa                                                     0.116536
# 10 Days in Asia                                                       0.094460
# 10 Days in Europe                                                     0.074929
#
# name                            ZÈRTZ  [redacted]  duck! duck! Go!     ebbes  \
# name
# ...and then, we held hands.  0.185706    0.165226         0.095863  0.127687
# ...und tschüss!              0.172880    0.065776         0.166939  0.199616
# 10 Days in Africa            0.336803    0.089493         0.284904  0.098230
# 10 Days in Asia              0.272813    0.054192         0.252753  0.079539
# 10 Days in Europe            0.338660    0.089756         0.235569  0.140514
#
# name                            iKNOW
# name
# ...and then, we held hands.  0.080030
# ...und tschüss!              0.059040
# 10 Days in Africa            0.087955
# 10 Days in Asia              0.076176
# 10 Days in Europe            0.147720
#
# [5 rows x 4582 columns]

# %%
# Top 20 similar board games
item_input = 'Wingspan'
item_sim = item_cf_df[item_input]
item_sim.index = item_cf_df.index.astype(str)
item_sim = item_sim[item_sim > 0].drop(item_input)
item_sim.sort_values(ascending=False).head(20)
# Out:
# name
# Azul                            0.889526
# 7 Wonders                       0.878789
# Terraforming Mars               0.877635
# Splendor                        0.872865
# Codenames                       0.870020
# The Castles of Burgundy         0.866457
# Pandemic                        0.865538
# 7 Wonders Duel                  0.864552
# Five Tribes                     0.856681
# Dominion                        0.855331
# Stone Age                       0.854436
# Carcassonne                     0.853066
# Patchwork                       0.852914
# Scythe                          0.852165
# Love Letter                     0.850472
# Kingdomino                      0.845257
# Sagrada                         0.842427
# Tzolk'in: The Mayan Calendar    0.842323
# The Quacks of Quedlinburg       0.840583
# King of Tokyo                   0.840457
# Name: Wingspan, dtype: float64
