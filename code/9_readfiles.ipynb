# %% [markdown]
# # Importing Libraries

# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# from pycaret.nlp import *

# %% [markdown]
# # Loading the Data

# %%
df = pd.read_csv('../datasets/gg_sheet/Board_Game_Cafe.csv')
df['tel'] = df['tel'].astype(str).str.zfill(10)
df.head()
# Out:
#                                        name       province  \
# 0                        Board Game Academy  กรุงเทพมหานคร
# 1                BoardVille Board Game Cafe  กรุงเทพมหานคร
# 2                   BOARDY BOARD GAMES CAFE  กรุงเทพมหานคร
# 3                    Box & Brew board game   กรุงเทพมหานคร
# 4  CoonCoon Boardgame Cafe and Music Studio  กรุงเทพมหานคร
#
#                                              contact  \
# 0          https://www.facebook.com/boardgameacademy
# 1                https://www.facebook.com/BoardVille
# 2  https://www.facebook.com/profile.php?id=100088...
# 3              https://www.facebook.com/boxandbrew40
# 4         https://www.facebook.com/cooncoonboardgame
#
#                                                  map        lat         lon  \
# 0              https://goo.gl/maps/4TieyswF3g8koJVJ8  13.731394  100.494173
# 1              https://goo.gl/maps/uFdNktSWtfHwFYvK7  13.779151  100.476615
# ...

# %%
# df.to_csv('../datasets/gg_sheet/board_game_cafe.csv', index=False, encoding ='utf-8-sig')

# %%
df = pd.read_csv('../datasets/gg_sheet/Category.csv')
df.head()
# Out:
#       cat_en   cat_th                                     description_en  \
# 0   Fantasy   แฟนตาซี  Fantasy games are those that have themes and s...
# 1  Adventure   ผจญภัย  Adventure games often have themes of heroism, ...
# 2    Wargame   สงคราม  Wargames are games that depict military action...
# 3   Fighting   ต่อสู้  Fighting games are those that encourage player...
# 4      Party  ปาร์ตี้  Party games are games that encourage social in...
#
#                                       description_th  \
# 0  เกมแฟนตาซีคือเกมที่มีธีมและสถานการณ์ที่มีอยู่ใ...
# 1  เกมผจญภัยมักมีธีมของความกล้าหาญ การสำรวจ และกา...
# 2  เกมสงครามเป็นเกมที่แสดงถึงการกระทำทางทหาร มีเร...
# 3  เกมต่อสู้เป็นเกมที่ส่งเสริมให้ผู้เล่นมีส่วนร่ว...
# 4  เกมปาร์ตี้เป็นเกมที่ส่งเสริมการมีปฏิสัมพันธ์ทา...
#
#                                              bgg_url  \
# 0  https://boardgamegeek.com/boardgamecategory/10...
# 1  https://boardgamegeek.com/boardgamecategory/10...
# ...

# %%
# df.to_csv('../datasets/gg_sheet/category.csv', index=False, encoding ='utf-8-sig')
